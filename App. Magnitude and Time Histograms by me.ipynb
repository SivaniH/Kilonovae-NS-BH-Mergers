# %% [markdown]
# ## Initial Hists - all wrong!

# %%
import numpy as np
#import pandas as pd
import json
import matplotlib.pyplot as plt
#from pprint import pprint

# %%
file = 'Downloads/Y4 Project/New models and notebooks/js_bns3_1011_clean.json'
with open(file) as f:  
    data = json.load(f)

# %%
klnv = data["kilonovae"]
kn_array = np.array(klnv)
kn1 = kn_array[0]
dp1 = kn1['data_points']

# %%
absmags_1 =[]
times_1=[] #times for photometry data in realisation=1 for all bands
appmags_1=[] #extracting app mags for realisation=1 for all bands
for i in range(len(dp1)):
    mags1=(dp1[i]['magnitude'])
    times1 = (dp1[i]['time'])
    absmags1 = (dp1[i]['absolute_magnitude'])
    appmags_1.append(mags1) 
    times_1.append(times1)
    absmags_1.append(absmags1)

# %%
#getting apparent and absolute magnitudes, times for g band in realisation 1
g_absmags_1 =[]
g_times_1=[]
g_appmags_1 = []
for g in np.arange(0, 420,6):
    gmags1=(appmags_1[g])
    gtimes1 = (times_1[g])
    gabsmags1 = (absmags_1[g])
    g_appmags_1.append(gmags1)
    g_times_1.append(gtimes1)
    g_absmags_1.append(gabsmags1)
    
#getting apparent and absolute magnitudes, times for i band in realisation 1
i_absmags_1 =[]
i_times_1=[]
i_appmags_1 = []
for i in np.arange(1, 420,6):
    imags1=(appmags_1[i])
    itimes1 = (times_1[i])
    iabsmags1 = (absmags_1[i])
    i_appmags_1.append(imags1)
    i_times_1.append(itimes1)
    i_absmags_1.append(iabsmags1)
    
#getting apparent and absolute magnitudes, times for r band in realisation 1
r_absmags_1 =[]
r_times_1=[]
r_appmags_1 = []
for r in np.arange(2, 420,6):
    rmags1=(appmags_1[r])
    rtimes1 = (times_1[r])
    rabsmags1 = (absmags_1[r])
    r_appmags_1.append(rmags1)
    r_times_1.append(rtimes1)
    r_absmags_1.append(rabsmags1)
    
    
#getting apparent and absolute magnitudes, times for u band in realisation 1
u_absmags_1 =[]
u_times_1=[]
u_appmags_1 = []
for u in np.arange(3, 420,6):
    umags1=(appmags_1[u])
    utimes1 = (times_1[u])
    uabsmags1 = (absmags_1[u])
    u_appmags_1.append(umags1)
    u_times_1.append(utimes1)
    u_absmags_1.append(uabsmags1)
    

#getting apparent and absolute magnitudes, times for y band in realisation 1
y_absmags_1 =[]
y_times_1=[]
y_appmags_1 = []
for y in np.arange(4, 420,6):
    ymags1=(appmags_1[y])
    ytimes1 = (times_1[y])
    yabsmags1 = (absmags_1[y])
    y_appmags_1.append(ymags1)
    y_times_1.append(ytimes1)
    y_absmags_1.append(yabsmags1)
    
#getting apparent and absolute magnitudes, times for z band in realisation 1
z_absmags_1 =[]
z_times_1=[]
z_appmags_1 = []
for z in np.arange(5, 420,6):
    zmags1=(appmags_1[z])
    ztimes1 = (times_1[z])
    zabsmags1 = (absmags_1[z])
    z_appmags_1.append(zmags1)
    z_times_1.append(ztimes1)
    z_absmags_1.append(zabsmags1)

# %%
plt.hist(g_appmags_1, bins=20)
plt.xlabel("Apparent Magnitude (g-band)")
plt.title("Histogram of Peak g-band Magnitudes for Realisation 1")
# Out:
# Text(0.5, 1.0, 'Histogram of Peak g-band Magnitudes for Realisation 1')

# %%
plt.hist(i_appmags_1, bins=20)
plt.xlabel("Apparent Magnitude (i-band)")
plt.title("Histogram of Peak i-band Magnitudes for Realisation 1")
# Out:
# Text(0.5, 1.0, 'Histogram of Peak i-band Magnitudes for Realisation 1')

# %%
plt.hist(r_appmags_1, bins=23)
plt.xlabel("Apparent Magnitude (r-band)")
plt.title("Histogram of Peak r-band Magnitudes for Realisation 1")
# Out:
# Text(0.5, 1.0, 'Histogram of Peak r-band Magnitudes for Realisation 1')

# %%
plt.hist(u_appmags_1, bins=20)
plt.xlabel("Apparent Magnitude (u-band)")
plt.title("Histogram of Peak u-band Magnitudes for Realisation 1")
# Out:
# Text(0.5, 1.0, 'Histogram of Peak u-band Magnitudes for Realisation 1')

# %%
plt.hist(y_appmags_1, bins=25)
plt.xlabel("Apparent Magnitude (y-band)")
plt.title("Histogram of Peak y-band Magnitudes for Realisation 1")
# Out:
# Text(0.5, 1.0, 'Histogram of Peak y-band Magnitudes for Realisation 1')

# %%
plt.hist(z_appmags_1, bins=25)
plt.xlabel("Apparent Magnitude (z-band)")
plt.title("Histogram of Peak z-band Magnitudes for Realisation 1")
# Out:
# Text(0.5, 1.0, 'Histogram of Peak z-band Magnitudes for Realisation 1')

# %%
# see what parameters cause these shapes
# plot g-band mag vs chirp mass

# histograms of absolute mags
# new hists : all on the same plot
# find out whts causng the islands on the histograms
# peaks later for larger z  

# use slightly finer toem sampling - should smooth out the peak times histograms 
# every hour or two hours 
# cgange bins command 


# do these for other parameers 
# could plot distributions of clours at peak - choose a band (eg. r-band at peak, then find out g band val at that time )
# ns binaries should be redder

# use neighbouring bands- andreoni paper has them 
# pick a fixed time even 
# roughly identify mags at t=0, 12, etc. and plot them 

# pick the flat prior model to make these histogras, - MW may be unrepresentative of the rest of the univrese
# read papers for next week

# plot of abs mags against mchirp or any other paramter 
# remake histogrmas for abs mags

# %%
np.min(g_appmags_1)
# Out:
# 21.441484182262176

# %%
np.min(g_times_1)
# Out:
# 0

# %% [markdown]
# ## Histograms of Peak Times

# %%
#g_times_1

# %% [markdown]
# ### testing stuff

# %%
MODEL = 3
FILEPATH = 'Downloads/Y4 Project/New models and notebooks/js_bns3_1011_clean.json'
with open(FILEPATH, mode="r") as file:
    data = json.load(file)
    
kilonovae = data["kilonovae"]

peak_app_mags = []
peak_times = []
for kn in kilonovae:
    app_mags = [float(kn["data_points"][i]["magnitude"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="i"]
    peak_am = np.min(app_mags)
    peak_index = np.argmin(app_mags)
    times = [float(kn["data_points"][i]["time"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="i"]
    peak_time = times[peak_index]
    peak_app_mags.append(peak_am)
    peak_time *= 24
    peak_times.append(peak_time)

# %%
peak_time
# Out:
# 14.608695652173914

# %%
i_appmags_1
# Out:
# [24.195452640663753,
#  22.83222703315694,
#  22.258948169451838,
#  21.923416317077766,
#  21.70837932884611,
#  21.569479360020622,
#  21.48514997809734,
#  21.4427743265877,
#  21.434285335849967,
#  21.453686073931006,
#  21.493998054252792,
#  21.548947448260858,
#  21.613043302679777,
#  21.679661039224722,
#  21.74364671203339,
#  21.800867843145735,
#  21.849050870221536,
#  21.88783440053612,
#  21.918094236257026,
#  21.94126767506324,
#  21.959095007863887,
#  21.97331520124065,
#  21.98486160266736,
#  21.992283177607668,
#  21.999072253623453,
#  22.006064509455765,
#  22.013750633906994,
#  22.021505706830844,
#  22.030097109227782,
#  22.039669087060112,
#  22.050446870157874,
#  22.06154399044765,
#  22.073973035017822,
#  22.085964140333232,
#  22.097443707690942,
#  22.110508766442383,
#  22.125036789301777,
#  22.141192886633156,
#  22.15915523825684,
#  22.17872790834642,
#  22.20001630460615,
#  22.222537319334172,
#  22.246520042985374,
#  22.2720077387857,
# ...

# %%
len(kilonovae)
# Out:
# 997

# %%
len(peak_app_mags)
# Out:
# 997

# %%
len(peak_times)
# Out:
# 997

# %%
#you're supposed to find the peak mag in each band for the whole data set (all realisations) and plot the histograms of those IDIOT

# %% [markdown]
# # Gaussian Prior

# %%
MODEL = 1
#filepath = f"...JSON cleaning/js_bns{MODEL}_{DATE}_clean.json.""
FILEPATH = '2411 jsons/js_bns3_2411_clean.json'
with open(FILEPATH, mode="r") as file:
    data = json.load(file)
    
kn_gauss = data["kilonovae"]

# %%
#making lists of peak apparent mags and peak times for the g band in the flat chirp mass distribution
g_pam_g = []
g_pt_g = []
for kn in kn_gauss:
    app_mags = [float(kn["data_points"][i]["magnitude"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="g"]
    peak_am = np.min(app_mags)
    peak_index = np.argmin(app_mags)
    times = [float(kn["data_points"][i]["time"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="g"]
    peak_time = times[peak_index]
    g_pam_g.append(peak_am)
    peak_time *= 24
    g_pt_g.append(peak_time)
    
    
#making lists of peak apparent mags and peak times for the i band in the Flat distribution
g_pam_i = []
g_pt_i = []
for kn in kn_gauss:
    app_mags = [float(kn["data_points"][i]["magnitude"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="i"]
    peak_am = np.min(app_mags)
    peak_index = np.argmin(app_mags)
    times = [float(kn["data_points"][i]["time"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="i"]
    peak_time = times[peak_index]
    g_pam_i.append(peak_am)
    peak_time *= 24
    g_pt_i.append(peak_time)
    
#making lists of peak apparent mags and peak times for the r band in the Flat distribution
g_pam_r = []
g_pt_r = []
for kn in kn_gauss:
    app_mags = [float(kn["data_points"][i]["magnitude"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="r"]
    peak_am = np.min(app_mags)
    peak_index = np.argmin(app_mags)
    times = [float(kn["data_points"][i]["time"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="r"]
    peak_time = times[peak_index]
    g_pam_r.append(peak_am)
    peak_time *= 24
    g_pt_r.append(peak_time)


#making lists of peak apparent mags and peak times for the u band in the Flat distributiong
g_pam_u = []
g_pt_u = []
for kn in kn_gauss:
    app_mags = [float(kn["data_points"][i]["magnitude"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="u"]
    peak_am = np.min(app_mags)
    peak_index = np.argmin(app_mags)
    times = [float(kn["data_points"][i]["time"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="u"]
    peak_time = times[peak_index]
    g_pam_u.append(peak_am)
    peak_time *= 24
    g_pt_u.append(peak_time)

    
#making lists of peak apparent mags and peak times for the y band in the Flat distribution
g_pam_y = []
g_pt_y = []
for kn in kn_gauss:
    app_mags = [float(kn["data_points"][i]["magnitude"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="y"]
    peak_am = np.min(app_mags)
    peak_index = np.argmin(app_mags)
    times = [float(kn["data_points"][i]["time"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="y"]
    peak_time = times[peak_index]
    g_pam_y.append(peak_am)
    peak_time *= 24
    g_pt_y.append(peak_time)

    
#making lists of peak apparent mags and peak times for the z band in the Flat distribution
g_pam_z = []
g_pt_z = []
for kn in kn_gauss:
    app_mags = [float(kn["data_points"][i]["magnitude"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="z"]
    peak_am = np.min(app_mags)
    peak_index = np.argmin(app_mags)
    times = [float(kn["data_points"][i]["time"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="z"]
    peak_time = times[peak_index]
    g_pam_z.append(peak_am)
    peak_time *= 24
    g_pt_z.append(peak_time)

# %%
len(g_pam_g), len(g_pt_g)
# Out:
# (1009, 1009)

# %%
app_mags = [float(kn["data_points"][i]["magnitude"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="z"]
peak_am = np.min(app_mags)
bright_am = np.max(app_mags)

# %%
peak_am, bright_am
# Out:
# (22.047773958417487, 24.773291058960645)

# %%
print(g_pam_z)
# Out:
# [20.88440122843526, 20.2458636716225, 21.73660917497772, 20.58581707823823, 21.919599449425426, 21.750356372473796, 20.93267945546966, 21.62693198754832, 19.981496063214266, 21.80188808510893, 21.524623197060944, 20.76667159394214, 21.133384774521442, 21.786918449951145, 21.848998546337608, 21.53749592790618, 21.117081645113203, 21.369848088682133, 21.691902100480167, 21.315169864306274, 21.87191494463061, 21.123676567857768, 21.791810219857375, 20.9239629034151, 22.117679894434197, 22.01398867009088, 21.745623876104254, 21.547926452392456, 21.579533350042492, 21.160937699199867, 21.61955866129654, 21.671536661604183, 21.500102629721205, 19.558496747924234, 21.433455268390844, 21.64310672639461, 21.373944141867458, 20.65033265562299, 21.375335244461038, 21.61631570983584, 19.249186097793984, 21.64547438458186, 21.110767988045236, 21.897748083124924, 21.660562530041503, 21.69697235968327, 21.564030008233885, 21.11771664679928, 21.91311962509058, 21.55415210504742, 20.327001782714635, 
# ...

# %% [markdown]
# # Flat Prior

# %%
MODEL = 1
#filepath = f"...JSON cleaning/js_bns{MODEL}_{DATE}_clean.json.""
FILEPATH = 'JSON cleaning/js_bns1_test_1_clean.json'
with open(FILEPATH, mode="r") as file:
    data = json.load(file)
    
kn_flat = data["kilonovae"]

# %%
#making lists of peak apparent mags and peak times for the g band in the flat chirp mass distribution
f_pam_g = []
f_pt_g = []
for kn in kn_flat:
    app_mags = [float(kn["data_points"][i]["magnitude"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="g"]
    peak_am = np.min(app_mags)
    peak_index = np.argmin(app_mags)
    times = [float(kn["data_points"][i]["time"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="g"]
    peak_time = times[peak_index]
    f_pam_g.append(peak_am)
    peak_time *= 24
    f_pt_g.append(peak_time)
    
    
#making lists of peak apparent mags and peak times for the i band in the Flat distribution
f_pam_i = []
f_pt_i = []
for kn in kn_flat:
    app_mags = [float(kn["data_points"][i]["magnitude"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="i"]
    peak_am = np.min(app_mags)
    peak_index = np.argmin(app_mags)
    times = [float(kn["data_points"][i]["time"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="i"]
    peak_time = times[peak_index]
    f_pam_i.append(peak_am)
    peak_time *= 24
    f_pt_i.append(peak_time)
    
#making lists of peak apparent mags and peak times for the r band in the Flat distribution
f_pam_r = []
f_pt_r = []
for kn in kn_flat:
    app_mags = [float(kn["data_points"][i]["magnitude"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="r"]
    peak_am = np.min(app_mags)
    peak_index = np.argmin(app_mags)
    times = [float(kn["data_points"][i]["time"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="r"]
    peak_time = times[peak_index]
    f_pam_r.append(peak_am)
    peak_time *= 24
    f_pt_r.append(peak_time)


#making lists of peak apparent mags and peak times for the u band in the Flat distribution
f_pam_u = []
f_pt_u = []
for kn in kn_flat:
    app_mags = [float(kn["data_points"][i]["magnitude"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="u"]
    peak_am = np.min(app_mags)
    peak_index = np.argmin(app_mags)
    times = [float(kn["data_points"][i]["time"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="u"]
    peak_time = times[peak_index]
    f_pam_u.append(peak_am)
    peak_time *= 24
    f_pt_u.append(peak_time)

    
#making lists of peak apparent mags and peak times for the y band in the Flat distribution
f_pam_y = []
f_pt_y = []
for kn in kn_flat:
    app_mags = [float(kn["data_points"][i]["magnitude"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="y"]
    peak_am = np.min(app_mags)
    peak_index = np.argmin(app_mags)
    times = [float(kn["data_points"][i]["time"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="y"]
    peak_time = times[peak_index]
    f_pam_y.append(peak_am)
    peak_time *= 24
    f_pt_y.append(peak_time)

    
#making lists of peak apparent mags and peak times for the z band in the Flat distribution
f_pam_z = []
f_pt_z = []
for kn in kn_flat:
    app_mags = [float(kn["data_points"][i]["magnitude"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="z"]
    peak_am = np.min(app_mags)
    peak_index = np.argmin(app_mags)
    times = [float(kn["data_points"][i]["time"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="z"]
    peak_time = times[peak_index]
    f_pam_z.append(peak_am)
    peak_time *= 24
    f_pt_z.append(peak_time)

# %% [markdown]
# ## Peak App. Mags

# %%
#plt.gca().invert_xaxis()
plt.hist(f_pam_g, bins = 30, color='blue', histtype='step', label= 'g')
plt.hist(f_pam_i, bins = 30, color='red', histtype='step', label='i' )
plt.hist(f_pam_r, bins = 30, color='green', histtype='step', label='r')
plt.hist(f_pam_y, bins = 30, color='cyan', histtype='step', label='y')
plt.hist(f_pam_u, bins = 30, color='orange', histtype='step', label='u')
plt.hist(f_pam_z, bins = 30, color='purple', histtype='step', label='z')
plt.xlabel("Apparent Magnitude")
plt.ylabel("Bin Count")
plt.legend()

# %% [markdown]
# ## Peak Times

# %%
plt.hist(f_pt_g, bins = np.arange(min(f_pt_g)-0.5, max(f_pt_g) +1.5, 1), color='blue', histtype='step', label= 'g', density=False)
plt.hist(f_pt_i, bins = np.arange(min(f_pt_i)-0.5, max(f_pt_i) +1.5, 1), color='red', histtype='step', label='i', density=False)
plt.hist(f_pt_r, bins = np.arange(min(f_pt_r)-0.5, max(f_pt_r) +1.5, 1), color='green', histtype='step', label='r', density=False)
plt.hist(f_pt_y, bins = np.arange(min(f_pt_y)-0.5, max(f_pt_y) +1.5, 1), color='cyan', histtype='step', label='y', density=False)
plt.hist(f_pt_u, bins = np.arange(min(f_pt_u)-0.5, max(f_pt_u) +1.5, 1), color='orange', histtype='step', label='u', density=False)
plt.hist(f_pt_z, bins = np.arange(min(f_pt_z)-0.5, max(f_pt_z) +1.5, 1), color='purple', histtype='step', label='z', density=False)
plt.xlabel("Peak Times (Hours)")
plt.ylabel("Bin Count")
plt.xlim(0, 27)
plt.legend()

#bin argument here makes sure the width of each bin stays the same

# %% [markdown]
# # Histogram Comparison of Gaussian and Flat Models

# %%
plt.hist(f_pam_g, bins = np.arange(min(f_pam_g)-0.5, max(f_pam_g) +1.5, 0.2), color='blue', histtype='step', label='Flat Prior', density=False)
plt.hist(f_pam_i, bins = np.arange(min(f_pam_i)-0.5, max(f_pam_i) +1.5, 0.2), color='blue', histtype='step', density=False)
plt.hist(f_pam_r, bins = np.arange(min(f_pam_r)-0.5, max(f_pam_r) +1.5, 0.2), color='blue', histtype='step', density=False)
plt.hist(f_pam_y, bins = np.arange(min(f_pam_y)-0.5, max(f_pam_y) +1.5, 0.2), color='blue', histtype='step', density=False)
plt.hist(f_pam_u, bins = np.arange(min(f_pam_u)-0.5, max(f_pam_u) +1.5, 0.2), color='blue', histtype='step', density=False)
plt.hist(f_pam_z, bins = np.arange(min(f_pam_z)-0.5, max(f_pam_z) +1.5, 0.2), color='blue', histtype='step', density=False)
plt.xlabel("Peak Times (Hours)")
plt.ylabel("Bin Count")
plt.xlim(0, 27)
plt.legend()

plt.hist(g_pam_g, bins = np.arange(min(g_pam_g)-0.5, max(g_pam_g) +1.5, 0.2), color='red', histtype='step', label='Gaussian Prior', density=False)
plt.hist(g_pam_i, bins = np.arange(min(g_pam_i)-0.5, max(g_pam_i) +1.5, 0.2), color='red', histtype='step', density=False)
plt.hist(g_pam_r, bins = np.arange(min(g_pam_r)-0.5, max(g_pam_r) +1.5, 0.2), color='red', histtype='step', density=False)
plt.hist(g_pam_y, bins = np.arange(min(g_pam_y)-0.5, max(g_pam_y) +1.5, 0.2), color='red', histtype='step', density=False)
plt.hist(g_pam_u, bins = np.arange(min(g_pam_u)-0.5, max(g_pam_u) +1.5, 0.2), color='red', histtype='step', density=False)
plt.hist(g_pam_z, bins = np.arange(min(g_pam_z)-0.5, max(g_pam_z) +1.5, 0.2), color='red', histtype='step', density=False)
plt.xlabel("Peak Times (Hours)")
plt.ylabel("Bin Count")
plt.xlim(0, 27)
plt.title("Histograms of Peak Magnitudes (All Bands) for Gaussian and Flat Priors", fontsize = 10)
plt.xlim(16, 27)
plt.legend()


#bins = 30 also works

# %%
plt.hist(f_pt_g, bins = np.arange(min(f_pt_g)-0.5, max(f_pt_g) +1.5, 1), color='blue', histtype='step', label='Flat Prior', density=False)
plt.hist(f_pt_i, bins = np.arange(min(f_pt_i)-0.5, max(f_pt_i) +1.5, 1), color='blue', histtype='step', density=False)
plt.hist(f_pt_r, bins = np.arange(min(f_pt_r)-0.5, max(f_pt_r) +1.5, 1), color='blue', histtype='step', density=False)
plt.hist(f_pt_y, bins = np.arange(min(f_pt_y)-0.5, max(f_pt_y) +1.5, 1), color='blue', histtype='step', density=False)
plt.hist(f_pt_u, bins = np.arange(min(f_pt_u)-0.5, max(f_pt_u) +1.5, 1), color='blue', histtype='step', density=False)
plt.hist(f_pt_z, bins = np.arange(min(f_pt_z)-0.5, max(f_pt_z) +1.5, 1), color='blue', histtype='step', density=False)
plt.xlabel("Peak Times (Hours)")
plt.ylabel("Bin Count")
plt.xlim(0, 27)
plt.legend()

plt.hist(g_pt_g, bins = np.arange(min(g_pt_g)-0.5, max(g_pt_g) +1.5, 1), color='red', histtype='step', label='Gaussian Prior', density=False)
plt.hist(g_pt_i, bins = np.arange(min(g_pt_i)-0.5, max(g_pt_i) +1.5, 1), color='red', histtype='step', density=False)
plt.hist(g_pt_r, bins = np.arange(min(g_pt_r)-0.5, max(g_pt_r) +1.5, 1), color='red', histtype='step', density=False)
plt.hist(g_pt_y, bins = np.arange(min(g_pt_y)-0.5, max(g_pt_y) +1.5, 1), color='red', histtype='step', density=False)
plt.hist(g_pt_u, bins = np.arange(min(g_pt_u)-0.5, max(g_pt_u) +1.5, 1), color='red', histtype='step', density=False)
plt.hist(g_pt_z, bins = np.arange(min(g_pt_z)-0.5, max(g_pt_z) +1.5, 1), color='red', histtype='step', density=False)
plt.xlabel("Peak Times (Hours)")
plt.ylabel("Bin Count")
plt.xlim(0, 27)
plt.title("Histograms of Peak Times (All Bands) for Gaussian and Flat Priors", fontsize = 11)
plt.legend()

# %% [markdown]
# # Flat Mass Ratio Sample

# %%
MODEL = 2
#filepath = f"...JSON cleaning/js_bns{MODEL}_{DATE}_clean.json.""
FILEPATH = 'JSON cleaning/js_bns2_test_2_clean.json'
with open(FILEPATH, mode="r") as file:
    data = json.load(file)
    
kn_flat = data["kilonovae"]

# %% [markdown]
# ## Apparent Magnitude Plot

# %%
#making lists of peak apparent mags and peak times for the g band in the flat chirp mass distribution
f_pam_g = []
f_pt_g = []
for kn in kn_flat:
    app_mags = [float(kn["data_points"][i]["magnitude"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="g"]
    peak_am = np.min(app_mags)
    peak_index = np.argmin(app_mags)
    times = [float(kn["data_points"][i]["time"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="g"]
    peak_time = times[peak_index]
    f_pam_g.append(peak_am)
    peak_time *= 24
    f_pt_g.append(peak_time)
    
    
#making lists of peak apparent mags and peak times for the i band in the Flat distribution
f_pam_i = []
f_pt_i = []
for kn in kn_flat:
    app_mags = [float(kn["data_points"][i]["magnitude"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="i"]
    peak_am = np.min(app_mags)
    peak_index = np.argmin(app_mags)
    times = [float(kn["data_points"][i]["time"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="i"]
    peak_time = times[peak_index]
    f_pam_i.append(peak_am)
    peak_time *= 24
    f_pt_i.append(peak_time)
    
#making lists of peak apparent mags and peak times for the r band in the Flat distribution
f_pam_r = []
f_pt_r = []
for kn in kn_flat:
    app_mags = [float(kn["data_points"][i]["magnitude"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="r"]
    peak_am = np.min(app_mags)
    peak_index = np.argmin(app_mags)
    times = [float(kn["data_points"][i]["time"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="r"]
    peak_time = times[peak_index]
    f_pam_r.append(peak_am)
    peak_time *= 24
    f_pt_r.append(peak_time)


#making lists of peak apparent mags and peak times for the u band in the Flat distribution
f_pam_u = []
f_pt_u = []
for kn in kn_flat:
    app_mags = [float(kn["data_points"][i]["magnitude"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="u"]
    peak_am = np.min(app_mags)
    peak_index = np.argmin(app_mags)
    times = [float(kn["data_points"][i]["time"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="u"]
    peak_time = times[peak_index]
    f_pam_u.append(peak_am)
    peak_time *= 24
    f_pt_u.append(peak_time)

    
#making lists of peak apparent mags and peak times for the y band in the Flat distribution
f_pam_y = []
f_pt_y = []
for kn in kn_flat:
    app_mags = [float(kn["data_points"][i]["magnitude"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="y"]
    peak_am = np.min(app_mags)
    peak_index = np.argmin(app_mags)
    times = [float(kn["data_points"][i]["time"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="y"]
    peak_time = times[peak_index]
    f_pam_y.append(peak_am)
    peak_time *= 24
    f_pt_y.append(peak_time)

    
#making lists of peak apparent mags and peak times for the z band in the Flat distribution
f_pam_z = []
f_pt_z = []
for kn in kn_flat:
    app_mags = [float(kn["data_points"][i]["magnitude"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="z"]
    peak_am = np.min(app_mags)
    peak_index = np.argmin(app_mags)
    times = [float(kn["data_points"][i]["time"]) for i in range(len(kn["data_points"])) if kn["data_points"][i]["band"]=="z"]
    peak_time = times[peak_index]
    f_pam_z.append(peak_am)
    peak_time *= 24
    f_pt_z.append(peak_time)

# %%
#plt.gca().invert_xaxis()
plt.hist(f_pam_u, bins = 30, histtype='step', label='u')
plt.hist(f_pam_g, bins = 30, histtype='step', label='g')
plt.hist(f_pam_r, bins = 30, histtype='step', label='r')
plt.hist(f_pam_i, bins = 30, histtype='step', label='i' )
plt.hist(f_pam_z, bins = 30, histtype='step', label='z')
plt.hist(f_pam_y, bins = 30, histtype='step', label='y')
plt.xlabel("Apparent Magnitude")
plt.ylabel("Bin Count")
plt.title('BNS Peak Apparent Magnitudes for Flat Prior')
plt.legend()

# %% [markdown]
# ## Peak Times Plot

# %%
plt.hist(f_pt_u, bins = np.arange(min(f_pt_u)-0.5, max(f_pt_u) +1.5, 1), histtype='step', label='u', density=False)
plt.hist(f_pt_g, bins = np.arange(min(f_pt_g)-0.5, max(f_pt_g) +1.5, 1), histtype='step', label= 'g', density=False)
plt.hist(f_pt_r, bins = np.arange(min(f_pt_r)-0.5, max(f_pt_r) +1.5, 1), histtype='step', label='r', density=False)
plt.hist(f_pt_i, bins = np.arange(min(f_pt_i)-0.5, max(f_pt_i) +1.5, 1), histtype='step', label='i', density=False)
plt.hist(f_pt_z, bins = np.arange(min(f_pt_z)-0.5, max(f_pt_z) +1.5, 1), histtype='step', label='z', density=False)
plt.hist(f_pt_y, bins = np.arange(min(f_pt_y)-0.5, max(f_pt_y) +1.5, 1), histtype='step', label='y', density=False)
plt.xlabel("Peak Times (Hours)")
plt.ylabel("Bin Count")
plt.title('BNS Merger Peak Timess for Flat Prior')
plt.xlim(0, 28)
plt.legend()

#bin argument here makes sure the width of each bin stays the same
