# %%
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt
from pprint import pprint

# %%
file = 'New json more params/js_bns3_1011_clean.json'
with open(file) as f:  
    data = json.load(f)
    
bands = ["g", "i", "r", "u", "y", "z"]

klnv = data["kilonovae"]

# %%
#len(kn_array) = 997
# Out:
# 997

# %%
data_points = []
for i in range(len(kn_array)):
    dp = kn_array[i]['data_points']
    data_points.append(dp)

# %%
#len(data_points) = 997
# Out:
# 997

# %% [markdown]
# # Peak Absolute Mags in g vs Mchirp

# %%
mchirp=[]
for i in range(len(klnv)):
    mc = klnv[i]["Mchirp"]
    mchirp.append(mc)

# %% [markdown]
# ## g band

# %%
g_absmags = []       #not necessary 
g_peak_absmags = []
gpam_index=[]         #not that necessary
#peak_g_mchirp=[]

for j in klnv:
    absmagsg = [float(j["data_points"][i]["absolute_magnitude"]) for i in range(len(j["data_points"])) if j["data_points"][i]["band"]=="g"]
    #g_absmags.append(absmagsg)
    peakabsmag = np.min(absmagsg)
    g_peak_absmags.append(peakabsmag)
    gpabsmagindex = np.argmin(absmagsg)
    gpam_index.append(gpabsmagindex)
#     pgm = g_mchirp[gpabsmagindex]
#     peak_g_mchirp.append(pgm)

# %%
#print(type(gpam_index)) = list
#print(len(gpam_index)) =997
#len(g_mchirp) = 997
#len(peak_g_mchirp) = 997

# %%
g_peak_absmags
# Out:
# [-15.855828149150451,
#  -15.733860117415642,
#  -15.54869193291167,
#  -15.491699691999415,
#  -15.312119699575298,
#  -15.695398584157381,
#  -15.509288349093733,
#  -15.723413573979645,
#  -15.739417499121306,
#  -15.554015675375432,
#  -15.883403015004276,
#  -15.803197483786782,
#  -12.01158236049623,
#  -15.893951113349086,
#  -12.762376295737262,
#  -15.908525468651277,
#  -15.81413599718368,
#  -15.748669901500708,
#  -15.695439887990574,
#  -12.472187995503443,
#  -15.833164070641537,
#  -15.406470763406372,
#  -12.445657936561645,
#  -15.345748336576548,
#  -13.176243447899846,
#  -15.843996946633933,
#  -15.466996833870759,
#  -15.880148399977447,
#  -15.581907373737884,
#  -15.608574114710692,
#  -15.841367347524308,
#  -15.781961066049579,
#  -15.536951452541306,
#  -15.389327026476021,
#  -14.277299058522832,
#  -15.964363802081362,
#  -15.355915594578988,
#  -15.378120109094553,
#  -15.531261589559954,
#  -15.925377740767015,
#  -15.511176296144374,
# ...

# %%
plt.scatter(mchirp, g_peak_absmags, s= 2 )
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = g) vs Mchirp- BNS3 ")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Mchirp [Msol]")
plt.savefig('Plots/BNS3/BNS3 peak mags vs mchirp in g.pdf')

# %% [markdown]
# ## i-band

# %%
i_absmags = []       #not necessary 
i_peak_absmags = []
ipam_index=[]         #not that necessary

for j in klnv:
    absmagsi = [float(j["data_points"][i]["absolute_magnitude"]) for i in range(len(j["data_points"])) if j["data_points"][i]["band"]=="i"]
    #g_absmags.append(absmagsg)
    peakabsmagi = np.min(absmagsi)
    i_peak_absmags.append(peakabsmagi)
    ipabsmagindex = np.argmin(absmagsi)
    ipam_index.append(ipabsmagindex)

# %%
#i_peak_absmags
#ipam_index

# %%
plt.scatter(mchirp, i_peak_absmags, s= 2, color='red' )
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = i) vs Mchirp ")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Mchirp [Msol]")
plt.savefig('Plots/BNS3/BNS3 peak mags vs mchirp in i.pdf')

# %% [markdown]
# ## r-band

# %%
r_absmags = []       #not necessary 
r_peak_absmags = []
rpam_index=[]         #not that necessary

for j in klnv:
    absmagsr = [float(j["data_points"][i]["absolute_magnitude"]) for i in range(len(j["data_points"])) if j["data_points"][i]["band"]=="r"]
    peakabsmagr = np.min(absmagsr)
    r_peak_absmags.append(peakabsmagr)
    rpabsmagindex = np.argmin(absmagsr)
    rpam_index.append(rpabsmagindex)

# %%
plt.scatter(mchirp, r_peak_absmags, s= 2, color='green' )
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = r) vs Mchirp ")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Mchirp [Msol]")
plt.savefig('Plots/BNS3/BNS3 peak mags vs mchirp in r.pdf')

# %% [markdown]
# ## u-band

# %%
u_absmags = []       #not necessary 
u_peak_absmags = []
upam_index=[]         #not that necessary

for j in klnv:
    absmagsu = [float(j["data_points"][i]["absolute_magnitude"]) for i in range(len(j["data_points"])) if j["data_points"][i]["band"]=="u"]
    peakabsmagu = np.min(absmagsu)
    u_peak_absmags.append(peakabsmagu)
    upabsmagindex = np.argmin(absmagsu)
    upam_index.append(upabsmagindex)
    
plt.scatter(mchirp, u_peak_absmags, s= 2, color='black' )
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = u) vs Mchirp ")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Mchirp [Msol]")
plt.savefig('Plots/BNS3/BNS3 peak mags vs mchirp in u.pdf')

# %% [markdown]
# ## y band

# %%
y_absmags = []       #not necessary 
y_peak_absmags = []
ypam_index=[]         #not that necessary

for j in klnv:
    absmagsy = [float(j["data_points"][i]["absolute_magnitude"]) for i in range(len(j["data_points"])) if j["data_points"][i]["band"]=="y"]
    peakabsmagy = np.min(absmagsy)
    y_peak_absmags.append(peakabsmagy)
    ypabsmagindex = np.argmin(absmagsy)
    ypam_index.append(ypabsmagindex)
    
plt.scatter(mchirp, y_peak_absmags, s= 2, color='indigo' )
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = y) vs Mchirp ")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Mchirp [Msol]")
plt.savefig('Plots/BNS3/BNS3 peak mags vs mchirp in y.pdf')

# %% [markdown]
# ## z band

# %%
z_absmags = []       #not necessary 
z_peak_absmags = []
zpam_index=[]         #not that necessary

for j in klnv:
    absmagsz = [float(j["data_points"][i]["absolute_magnitude"]) for i in range(len(j["data_points"])) if j["data_points"][i]["band"]=="z"]
    peakabsmagz = np.min(absmagsz)
    z_peak_absmags.append(peakabsmagz)
    zpabsmagindex = np.argmin(absmagsz)
    zpam_index.append(zpabsmagindex)
    
plt.scatter(mchirp, z_peak_absmags, s= 2, color='orange' )
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = z) vs Mchirp ")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Mchirp [Msol]")
plt.savefig('Plots/BNS3/BNS3 peak mags vs mchirp in z.pdf')

# %% [markdown]
# # Peak Abs. Magnitudes vs q

# %%
q=[]
for i in range(len(klnv)):
    mr = klnv[i]["q"]
    q.append(mr)

# %%
plt.scatter(q, g_peak_absmags, s= 3 )
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = g) vs Mass Ratio ")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Mass Ratio")
plt.savefig('Plots/BNS3/BNS3 peak mags vs q in g.pdf')

# %%
plt.scatter(q, i_peak_absmags, s= 3, color = 'r' )
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = i) vs Mass Ratio ")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Mass Ratio")
# Out:
# Text(0.5, 0, 'Mass Ratio')

# %%
plt.scatter(q, r_peak_absmags, s= 3, color = 'g' )
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = r) vs Mass Ratio ")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Mass Ratio")
# Out:
# Text(0.5, 0, 'Mass Ratio')

# %% [markdown]
# # New JSON file with q fixed

# %%
file2 = '2411 jsons/js_bns3_2411_clean.json'
with open(file2) as f:  
    data = json.load(f)
    
bands = ["g", "i", "r", "u", "y", "z"]

klnv2 = data["kilonovae"]

# %%
q=[]
for i in range(len(klnv2)):
    mr = klnv2[i]["q"]
    q.append(mr)

# %% [markdown]
# ## gband

# %%
g_absmags = []       #not necessary 
g_peak_absmags = []
gpam_index=[]         #not that necessary
#peak_g_mchirp=[]

for j in klnv2:
    absmagsg = [float(j["data_points"][i]["absolute_magnitude"]) for i in range(len(j["data_points"])) if j["data_points"][i]["band"]=="g"]
    #g_absmags.append(absmagsg)
    peakabsmag = np.min(absmagsg)
    g_peak_absmags.append(peakabsmag)
    gpabsmagindex = np.argmin(absmagsg)
    gpam_index.append(gpabsmagindex)
#     pgm = g_mchirp[gpabsmagindex]
#     peak_g_mchirp.append(pgm)

# %%
plt.scatter(q, g_peak_absmags, s= 3 )
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = g) vs Mass Ratio ")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Mass Ratio")
plt.savefig('Plots/2411/2411 peak mags vs q in g.pdf')

# %% [markdown]
# ## i band

# %%
i_absmags = []       #not necessary 
i_peak_absmags = []
ipam_index=[]         #not that necessary

for j in klnv2:
    absmagsi = [float(j["data_points"][i]["absolute_magnitude"]) for i in range(len(j["data_points"])) if j["data_points"][i]["band"]=="i"]
    #g_absmags.append(absmagsg)
    peakabsmagi = np.min(absmagsi)
    i_peak_absmags.append(peakabsmagi)
    ipabsmagindex = np.argmin(absmagsi)
    ipam_index.append(ipabsmagindex)
    
plt.scatter(q, i_peak_absmags, s= 3, color='red' )
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = i) vs Mass Ratio ")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Mass Ratio")
plt.savefig('Plots/2411/2411 peak mags vs q in i.pdf')

# %% [markdown]
# ## r band

# %%
r_absmags = []       #not necessary 
r_peak_absmags = []
rpam_index=[]         #not that necessary

for j in klnv2:
    absmagsr = [float(j["data_points"][i]["absolute_magnitude"]) for i in range(len(j["data_points"])) if j["data_points"][i]["band"]=="r"]
    peakabsmagr = np.min(absmagsr)
    r_peak_absmags.append(peakabsmagr)
    rpabsmagindex = np.argmin(absmagsr)
    rpam_index.append(rpabsmagindex)
    
plt.scatter(q, r_peak_absmags, s= 3, color='green' )
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = r) vs Mass Ratio ")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Mass Ratio")
plt.savefig('Plots/2411/2411 peak mags vs q in r.pdf')

# %%
u_absmags = []       #not necessary 
u_peak_absmags = []
upam_index=[]         #not that necessary

for j in klnv2:
    absmagsu = [float(j["data_points"][i]["absolute_magnitude"]) for i in range(len(j["data_points"])) if j["data_points"][i]["band"]=="u"]
    peakabsmagu = np.min(absmagsu)
    u_peak_absmags.append(peakabsmagu)
    upabsmagindex = np.argmin(absmagsu)
    upam_index.append(upabsmagindex)
    
plt.scatter(q, u_peak_absmags, s= 3, color='black' )
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = u) vs Mass Ratio ")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Mass Ratio")
plt.savefig('Plots/2411/2411 peak mags vs q in u.pdf')

# %%
y_absmags = []       #not necessary 
y_peak_absmags = []
ypam_index=[]         #not that necessary

for j in klnv2:
    absmagsy = [float(j["data_points"][i]["absolute_magnitude"]) for i in range(len(j["data_points"])) if j["data_points"][i]["band"]=="y"]
    peakabsmagy = np.min(absmagsy)
    y_peak_absmags.append(peakabsmagy)
    ypabsmagindex = np.argmin(absmagsy)
    ypam_index.append(ypabsmagindex)
    
plt.scatter(q, y_peak_absmags, s= 3, color='purple' )
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = y) vs Mass Ratio ")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Mass Ratio")
plt.savefig('Plots/2411/2411 peak mags vs q in y.pdf')

# %%
z_absmags = []       #not necessary 
z_peak_absmags = []
zpam_index=[]         #not that necessary

for j in klnv2:
    absmagsz = [float(j["data_points"][i]["absolute_magnitude"]) for i in range(len(j["data_points"])) if j["data_points"][i]["band"]=="z"]
    peakabsmagz = np.min(absmagsz)
    z_peak_absmags.append(peakabsmagz)
    zpabsmagindex = np.argmin(absmagsz)
    zpam_index.append(zpabsmagindex)
    
plt.scatter(q, z_peak_absmags, s= 3, color='orange' )
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = z) vs Mass Ratio ")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Mass Ratio")
plt.savefig('Plots/2411/2411 peak mags vs q in z.pdf')

# %%
plt.scatter(q, g_peak_absmags, s= 3, color='blue', label="g" )
plt.scatter(q, i_peak_absmags, s= 3, color='green', label="i" )
plt.scatter(q, r_peak_absmags, s= 3, color='red', label="r"  )
plt.scatter(q, u_peak_absmags, s= 3, color='black', label="u"  )
plt.scatter(q, y_peak_absmags, s= 3, color='purple', label="y"  )
plt.scatter(q, z_peak_absmags, s= 3, color='orange', label="z"  )

plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in all bands) vs Mass Ratio ")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Mass Ratio")
plt.legend()
plt.savefig('Plots/2411/2411 peak mags vs q in all bands.pdf')

# %% [markdown]
# # Viewing Angle (CosTheta)

# %%
cos_theta=[]
for i in range(len(klnv2)):
    ct = klnv2[i]["cos_theta"]
    cos_theta.append(ct)

# %% [markdown]
# ## g band

# %%
plt.scatter(cos_theta, g_peak_absmags, s= 3 )
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = g) vs Viewing Angle ")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Viewing Angle")
plt.savefig('Plots/2411/2411 peak mags vs costheta in g.pdf')

# %% [markdown]
# ## i band

# %%
plt.scatter(cos_theta, i_peak_absmags, s= 3, color='green' )
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = i) vs Viewing Angle ")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Viewing Angle")
plt.savefig('Plots/2411/2411 peak mags vs costheta in i.pdf')

# %% [markdown]
# ## r band

# %%
plt.scatter(cos_theta, r_peak_absmags, s= 3, color='red' )
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = r) vs Viewing Angle ")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Viewing Angle")
plt.savefig('Plots/2411/2411 peak mags vs costheta in r.pdf')

# %% [markdown]
# ## u band

# %%
u_absmags = []       #not necessary 
u_peak_absmags = []
upam_index=[]         #not that necessary

for j in klnv2:
    absmagsu = [float(j["data_points"][i]["absolute_magnitude"]) for i in range(len(j["data_points"])) if j["data_points"][i]["band"]=="u"]
    peakabsmagu = np.min(absmagsu)
    u_peak_absmags.append(peakabsmagu)
    upabsmagindex = np.argmin(absmagsu)
    upam_index.append(upabsmagindex)
    
plt.scatter(cos_theta, u_peak_absmags, s= 3, color='black' )
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = u) vs Viewing Angle ")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Viewing Angle")
plt.savefig('Plots/2411/2411 peak mags vs costheta in u.pdf')

# %% [markdown]
# ## y band

# %%
y_absmags = []       #not necessary 
y_peak_absmags = []
ypam_index=[]         #not that necessary

for j in klnv2:
    absmagsy = [float(j["data_points"][i]["absolute_magnitude"]) for i in range(len(j["data_points"])) if j["data_points"][i]["band"]=="y"]
    peakabsmagy = np.min(absmagsy)
    y_peak_absmags.append(peakabsmagy)
    ypabsmagindex = np.argmin(absmagsy)
    ypam_index.append(ypabsmagindex)
    
plt.scatter(cos_theta, y_peak_absmags, s= 3, color='indigo' )
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = y) vs Viewing Angle ")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Viewing Angle")
plt.savefig('Plots/2411/2411 peak mags vs costheta in y.pdf')

# %% [markdown]
# ## z band

# %%
z_absmags = []       #not necessary 
z_peak_absmags = []
zpam_index=[]         #not that necessary

for j in klnv2:
    absmagsz = [float(j["data_points"][i]["absolute_magnitude"]) for i in range(len(j["data_points"])) if j["data_points"][i]["band"]=="z"]
    peakabsmagz = np.min(absmagsz)
    z_peak_absmags.append(peakabsmagz)
    zpabsmagindex = np.argmin(absmagsz)
    zpam_index.append(zpabsmagindex)    

plt.scatter(cos_theta, z_peak_absmags, s= 3, color='orange' )
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = z) vs Viewing Angle ")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Viewing Angle")
plt.savefig('Plots/2411/2411 peak mags vs costheta in z.pdf')

# %% [markdown]
# ## all bands

# %%
plt.scatter(cos_theta, z_peak_absmags, s= 3, color='orange', label= "z")
plt.scatter(cos_theta, y_peak_absmags, s= 3, color='indigo', label= "y" )
plt.scatter(cos_theta, u_peak_absmags, s= 3, color='black', label= "u" )
plt.scatter(cos_theta, r_peak_absmags, s= 3, color='red', label= "r" )
plt.scatter(cos_theta, i_peak_absmags, s= 3, color='green', label= "i" )
plt.scatter(cos_theta, g_peak_absmags, s= 3, color='blue', label= "g" )
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in all bands) vs Viewing Angle ")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Viewing Angle")
plt.legend()
plt.savefig('Plots/2411/2411 peak mags vs costheta for all bands.pdf')

# %% [markdown]
# # Disk Fraction

# %%
disk_frac=[]
for i in range(len(klnv2)):
    df = klnv2[i]["disk_frac"]
    disk_frac.append(df)

# %%
plt.scatter(disk_frac, g_peak_absmags, s= 3, color='blue')
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = g) vs Disk Fraction ")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Disk Fraction")
plt.savefig('Plots/2411/2411 peak mags vs diskfrac in g.pdf')

# %%
plt.scatter(disk_frac, i_peak_absmags, s= 3, color='green')
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = i) vs Disk Fraction ")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Disk Fraction")
plt.savefig('Plots/2411/2411 peak mags vs diskfrac in i.pdf')

# %%
plt.scatter(disk_frac, r_peak_absmags, s= 3, color='red')
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = r) vs Disk Fraction ")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Disk Fraction")
plt.savefig('Plots/2411/2411 peak mags vs diskfrac in r.pdf')

# %% [markdown]
# # Redshift

# %%
redshift=[]
for i in range(len(klnv2)):
    z = klnv2[i]["redshift"]
    redshift.append(z)

# %%
plt.scatter(redshift, g_peak_absmags, s= 3, color='blue')
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = g) vs Redshift")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Redshift")
plt.savefig('Plots/2411/2411 peak mags vs redshift in g.pdf')

# %%
plt.scatter(redshift, i_peak_absmags, s= 3, color='green')
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = i) vs Redshift")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Redshift")
plt.savefig('Plots/2411/2411 peak mags vs redshift in i.pdf')

# %%
plt.scatter(redshift, r_peak_absmags, s= 3, color='red')
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = r) vs Redshift")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Redshift")
plt.savefig('Plots/2411/2411 peak mags vs redshift in r.pdf')

# %% [markdown]
# # Luminosity Distance - same as z

# %%
lum_dist=[]
for i in range(len(klnv2)):
    ld = klnv2[i]["lumdist"]
    lum_dist.append(ld)

# %%
plt.scatter(lum_dist, g_peak_absmags, s= 3, color='blue')
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = g) vs Luminosity Distance")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Luminosity Distance")
plt.savefig('Plots/2411/2411 peak mags vs lumdist in g.pdf')

# %% [markdown]
# # Shocked Fraction

# %%
shock_frac=[]
for i in range(len(klnv2)):
    sf = klnv2[i]["shock_frac"]
    shock_frac.append(sf)

# %%
plt.scatter(shock_frac, g_peak_absmags, s= 3, color='blue')
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = g) vs Shocked Fraction")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Shocked Fraction")
plt.savefig('Plots/2411/2411 peak mags vs shockfrac in g.pdf')

# %%
plt.scatter(shock_frac, i_peak_absmags, s= 3, color='green')
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = i) vs Shocked Fraction")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Shocked Fraction")
plt.savefig('Plots/2411/2411 peak mags vs shockfrac in i.pdf')

# %%
plt.scatter(shock_frac, r_peak_absmags, s= 3, color='red')
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = r) vs Shocked Fraction")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Shocked Fraction")
plt.savefig('Plots/2411/2411 peak mags vs shockfrac in r.pdf')

# %% [markdown]
# # Mchirp

# %%
mchirp=[]
for i in range(len(klnv2)):
    mc = klnv2[i]["Mchirp"]
    mchirp.append(mc)

# %%
plt.scatter(mchirp, g_peak_absmags, s= 2 )
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = g) vs Mchirp")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Mchirp [Msol]")
plt.savefig('Plots/2411/2411 peak mags vs mchirp in g.pdf')

# %%
plt.scatter(mchirp, i_peak_absmags, s= 2, color='green' )
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = i) vs Mchirp")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Mchirp [Msol]")
plt.savefig('Plots/2411/2411 peak mags vs mchirp in i.pdf')

# %%
plt.scatter(mchirp, r_peak_absmags, s= 2, color='red' )
plt.gca().invert_yaxis()
plt.title("Peak Absolute Magnitudes (in band = r) vs Mchirp")
plt.ylabel("Peak Absolute Magnitude")
plt.xlabel("Mchirp [Msol]")
plt.savefig('Plots/2411/2411 peak mags vs mchirp in r.pdf')
